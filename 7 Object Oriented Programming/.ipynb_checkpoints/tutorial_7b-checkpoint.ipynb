# %% [markdown]
# ### 1
#
# What does a subclass inherit from its superclass?

# %% [markdown]
# attributes and methods

# %% [markdown]
# ### 2
#
# What are the benefits of having class `B` extend or inherit from class `A`?

# %% [markdown]
# can reuse attributes and methods, reduced redundancy

# %% [markdown]
# ### 3
#
# Look at the following class definition. What is the name of the superclass? What is the
# name of the subclass?
#
# ```python
# class Tiger(Felis):
# ```

# %%
Felis
Tiger

# %% [markdown]
# ### 4
#
# Describe what the `__init__` method should do in a class that extends another class.

# %% [markdown]
# it should call super().__init__()

# %% [markdown]
# ### 5
#
# Look at the following class definition:
#
# ```python
# class Beverage:
#     def __init__(self, bev_name):
#         self._bev_name = bev_name
# ```
#
# Write the code for a class named `Cola` that is a subclass of the `Beverage` class. The `Cola` class’s `__init__` method should call the Beverage class’s `__init__` method, passing 'cola' as an argument.

# %%
class Beverage:
    def __init__(self, bev_name):
        self._bev_name = bev_name

class Cola(Beverage):
    def __init__(self):
        super().__init__("cola")

# %% [markdown]
# ### 6
#
# What is an overridden method?

# %% [markdown]
# Same name but different method.

# %% [markdown]
# ### 7
#
# Look at the following class definitions:
#
# ```python
# class Plant:
#     def __init__(self, plant_type):
#         self._plant_type = plant_type
#     def message(self):
#         print ("I'm a plant")
#
# class Tree(Plant):
#     def __init__(self):
#         super().__init__('tree')
#     def message(self):
#         print ("I'm a tree")
# ```
#
# Given these class definitions, what will the following statements display?
#
# ```python
# p = Plant('sapling')
# t = Tree()
# p.message()
# t.message()
# ```

# %% [markdown]
# I am a plant
# I am a tree

# %% [markdown]
# ### 8
#
# Class `B` extends class `A`. Class `A` defines an `__str__` method that returns the string representation of its instance variables. Class `B` defines a single variable named `_age`. Write the code to define the `__str__` method for class `B`. This method should return the combined string information from both classes. Label the data for `_age` with the string "Age: ".

# %%
class A:
    def __init__(self):
        self._var = "hi"

    def __str__(self):
        return self._var

class B(A):
    def __init__(self, age):
        super().__init__()
        self._age = age

    def __str__(self):
        return "Var: " + self._var + " Age: " + str(self._age)

a = A()
b = B(10)

print(b)
# Out:
# Var: hi Age: 10

# %% [markdown]
# (a) Using this diagram to explain the following terms:
#
#     (i) encapsulation,
#     (ii) inheritance,
#     (iii) polymorphism.
#
# (b) Explain what is meant by data hiding.
#
# (c) For each of the following classes give one other possible private attribute:
#
#     (i) SalesStaff,
#     (ii) TemporaryStaff.
#
# Some permanent staff earn commission on each sale that they make. This commission is a percentage of the value of each sale. However, the greater the total value of the sales that they make the higher the percentage used.
#
# (d) Describe two ways that the diagram could be altered to accommodate this additional information.
#
# (e) Give two advantages of using an object-oriented programming language.
