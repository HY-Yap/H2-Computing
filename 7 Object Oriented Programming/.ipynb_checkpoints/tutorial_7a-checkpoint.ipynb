# %% [markdown]
# ### 1
#
# What is the difference between a class and an object?

# %% [markdown]
# A class is code that specifies the data attributes and methods of a particular type of object, while an object is an instance created from a class.

# %% [markdown]
# ### 2
#
# (i) What is encapsulation?
#
# (ii) How is data hiding achieved in a class?

# %% [markdown]
# (i) encapsulation is combining data and procedure into a single object
#
# (ii) data hiding is aciieved by making an object's data attributes private

# %% [markdown]
# ### 3
#
# The following statement calls an object’s method. What is the name of the method? What is the name of the variable that references the object?
#
# ```python
# wallet.get_dollar()
# ```

# %% [markdown]
# get_dollar()
# wallet

# %% [markdown]
# ### 4
#
# When the `__init__` method executes, what does the `self` parameter reference?

# %% [markdown]
# the specific object that the method is working on

# %% [markdown]
# ### 5
#
# How do you call the `__str__` method?

# %% [markdown]
# print the object

# %% [markdown]
# ### 6
#
# Suppose `my_car` is the name of a variable that references an object, and `go` is the name of a method. Write a statement that uses the `my_car` variable to call the `go` method. (You do not have to pass any arguments to the go method.)

# %% [markdown]
# my_car.go()

# %% [markdown]
# ### 7
#
# Draw a class diagram for `Book`. The `Book` class has data attributes for title, author’s
# name, publisher’s name and their corresponding accessor and mutator methods for
# each attribute.

# %% [markdown]
# see ipad
